# %%
import string
import re
import numpy as np
from pickle import dump, load
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.utils import to_categorical
from keras.models import Sequential, load_model
from keras.layers import Dense, LSTM, Embedding, Input
from random import randint
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# **Data Preparation**

# %%
def load_doc(filename):
    file = open(filename, 'r', encoding='utf-8')
    text = file.read()
    file.close()
    return text

# %%
def clean_doc(doc):
    doc = doc.replace('--', ' ')
    tokens = doc.split()
    re_punc = re.compile(f"[{re.escape(string.punctuation)}]")
    tokens = [re_punc.sub('', w) for w in tokens]
    tokens = [w for w in tokens if w.isalpha()]
    tokens = [w.lower() for w in tokens]
    return tokens

# %%
def save_doc(lines, filename):
    data = '\n'.join(lines)
    file = open(filename, 'w')
    file.write(data)
    file.close()

# %%
in_filename = '/kaggle/input/the-plato/republic_clean.txt'
doc = load_doc(in_filename)
tokens = clean_doc(doc)
print(f"Total tokens: {len(tokens)}")
print(f"Unique tokens: {len(set(tokens))}")
# Out:
# Total tokens: 117342
# Unique tokens: 7323

# %%
# organize into sequences of tokens
length = 50 + 1
sequences = list()
for i in range(length, len(tokens)):
    seq = tokens[i-length : i]
    line = ' '.join(seq)
    sequences.append(line)
print(f"Total sequences: {len(sequences)}")

out_filename = 'republic_sequences.txt'
save_doc(sequences, out_filename)
# Out:
# Total sequences: 117291

# %% [markdown]
# **Train Language Model**

# %%
def define_model(vocab_size, seq_length):
    model = Sequential()
    model.add(Input(shape = (seq_length,)))
    model.add(Embedding(vocab_size, 50))
    model.add(LSTM(100, return_sequences = True))
    model.add(LSTM(100))
    model.add(Dense(100, activation = 'relu'))
    model.add(Dense(vocab_size, activation = 'softmax'))
    model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
    model.summary()
    return model

# %%
in_filename = 'republic_sequences.txt'
doc = load_doc(in_filename)
lines = doc.split('\n')

# %%
# integer encode sequences of words
tokenizer = Tokenizer()
tokenizer.fit_on_texts(lines)
sequences = tokenizer.texts_to_sequences(lines)

# %%
vocab_size = len(tokenizer.word_index) + 1
sequences = np.array(sequences)
# separate into input and output
x, y = sequences[:, :-1], sequences[:, -1]
y = to_categorical(y, num_classes = vocab_size)
seq_length = x.shape[1]

# %%
model = define_model(vocab_size, seq_length)
model.fit(x, y, batch_size = 128, epochs = 100)
model.save('model.h5') # save model to file
dump(tokenizer, open('tokenizer.pkl', 'wb')) # save the tokenizer
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (None, 50, 50)         │       366,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 50, 100)        │        60,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 100)            │        80,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 7324)           │       739,724 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,256,824 (4.79 MB)
#  Trainable params: 1,256,824 (4.79 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 13s 12ms/step - accuracy: 0.0614 - loss: 6.4439
# Epoch 2/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.1028 - loss: 5.7122
# Epoch 3/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.1271 - loss: 5.4772
# Epoch 4/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.1456 - loss: 5.3005
# Epoch 5/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.1548 - loss: 5.1762
# Epoch 6/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.1607 - loss: 5.0818
# Epoch 7/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.1649 - loss: 4.9802
# Epoch 8/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.1684 - loss: 4.9183
# Epoch 9/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.1737 - loss: 4.8241
# Epoch 10/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.1789 - loss: 4.7542
# Epoch 11/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.1823 - loss: 4.6877
# Epoch 12/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.1857 - loss: 4.6095
# Epoch 13/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.1878 - loss: 4.5616
# Epoch 14/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.1896 - loss: 4.4986
# Epoch 15/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.1938 - loss: 4.4514
# Epoch 16/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.1965 - loss: 4.3875
# Epoch 17/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.1965 - loss: 4.3538
# Epoch 18/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.1992 - loss: 4.3032
# Epoch 19/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2016 - loss: 4.2660
# Epoch 20/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2039 - loss: 4.2291
# Epoch 21/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2079 - loss: 4.1734
# Epoch 22/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2118 - loss: 4.1396
# Epoch 23/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2121 - loss: 4.1125
# Epoch 24/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2174 - loss: 4.0685
# Epoch 25/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2195 - loss: 4.0286
# Epoch 26/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2208 - loss: 4.0073
# Epoch 27/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2258 - loss: 3.9612
# Epoch 28/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2256 - loss: 3.9565
# Epoch 29/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2301 - loss: 3.9106
# Epoch 30/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2348 - loss: 3.8850
# Epoch 31/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2335 - loss: 3.8742
# Epoch 32/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2382 - loss: 3.8410
# Epoch 33/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2411 - loss: 3.8165
# Epoch 34/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2422 - loss: 3.8049
# Epoch 35/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2448 - loss: 3.7701
# Epoch 36/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2489 - loss: 3.7439
# Epoch 37/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2512 - loss: 3.7298
# Epoch 38/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2552 - loss: 3.7038
# Epoch 39/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2571 - loss: 3.6811
# Epoch 40/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2595 - loss: 3.6618
# Epoch 41/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2617 - loss: 3.6428
# Epoch 42/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2644 - loss: 3.6201
# Epoch 43/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2647 - loss: 3.6008
# Epoch 44/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2674 - loss: 3.5882
# Epoch 45/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2706 - loss: 3.5643
# Epoch 46/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2727 - loss: 3.5552
# Epoch 47/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2761 - loss: 3.5275
# Epoch 48/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2785 - loss: 3.5087
# Epoch 49/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2806 - loss: 3.4897
# Epoch 50/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2825 - loss: 3.4719
# Epoch 51/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2867 - loss: 3.4518
# Epoch 52/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2867 - loss: 3.4328
# Epoch 53/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2930 - loss: 3.4097
# Epoch 54/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2927 - loss: 3.3953
# Epoch 55/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.2962 - loss: 3.3804
# Epoch 56/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3006 - loss: 3.3584
# Epoch 57/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3001 - loss: 3.3560
# Epoch 58/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3042 - loss: 3.3273
# Epoch 59/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3048 - loss: 3.3234
# Epoch 60/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3070 - loss: 3.2993
# Epoch 61/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3114 - loss: 3.2683
# Epoch 62/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3137 - loss: 3.2560
# Epoch 63/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3134 - loss: 3.2550
# Epoch 64/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3183 - loss: 3.2228
# Epoch 65/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3192 - loss: 3.2177
# Epoch 66/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3205 - loss: 3.2047
# Epoch 67/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3274 - loss: 3.1756
# Epoch 68/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3290 - loss: 3.1595
# Epoch 69/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3294 - loss: 3.1456
# Epoch 70/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3322 - loss: 3.1350
# Epoch 71/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3358 - loss: 3.1099
# Epoch 72/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3388 - loss: 3.0979
# Epoch 73/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3401 - loss: 3.0782
# Epoch 74/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3429 - loss: 3.0687
# Epoch 75/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3477 - loss: 3.0412
# Epoch 76/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3507 - loss: 3.0317
# Epoch 77/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3500 - loss: 3.0277
# Epoch 78/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3536 - loss: 3.0014
# Epoch 79/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3560 - loss: 2.9911
# Epoch 80/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3585 - loss: 2.9780
# Epoch 81/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3613 - loss: 2.9570
# Epoch 82/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3620 - loss: 2.9466
# Epoch 83/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3646 - loss: 2.9396
# Epoch 84/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3679 - loss: 2.9169
# Epoch 85/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3686 - loss: 2.9067
# Epoch 86/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3735 - loss: 2.8836
# Epoch 87/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3730 - loss: 2.8832
# Epoch 88/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3800 - loss: 2.8546
# Epoch 89/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3829 - loss: 2.8367
# Epoch 90/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3806 - loss: 2.8347
# Epoch 91/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3863 - loss: 2.8138
# Epoch 92/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3862 - loss: 2.8045
# Epoch 93/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3881 - loss: 2.8013
# Epoch 94/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3924 - loss: 2.7820
# Epoch 95/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3922 - loss: 2.7712
# Epoch 96/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3959 - loss: 2.7583
# Epoch 97/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.3983 - loss: 2.7436
# Epoch 98/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.4029 - loss: 2.7220
# Epoch 99/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.4014 - loss: 2.7266
# Epoch 100/100
# 917/917 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.4031 - loss: 2.7055

# %%
def generate_seq(model, tokenizer, seq_length, seed_text, n_words):
    result = list()
    in_text = seed_text
    for _ in range (n_words):
        encoded = tokenizer.texts_to_sequences([in_text])[0]
        encoded = pad_sequences([encoded], maxlen = seq_length, truncating = 'pre')
        yhat = model.predict(encoded, verbose = 0)
        yhat = np.argmax(yhat, axis = -1)
        out_word = ''
        for word, index in  tokenizer.word_index.items():
            if index == yhat:
                out_word = word
                break
        in_text += ' ' + out_word
        result.append(out_word)
    return ' '.join(result)

# %%
in_filename = 'republic_sequences.txt'
doc = load_doc(in_filename)
lines = doc.split('\n')
# input : line.size() - output_size
seq_length = len(lines[0].split()) - 1

# %%
model = load_model('model.h5')
tokenizer = load(open('tokenizer.pkl', 'rb'))

# %%
seed_text = lines[randint(0, len(lines))] # select a random line
print(seed_text + '\n')

generated = generate_seq(model, tokenizer, seq_length, seed_text, 75)
print(generated)
# Out:
# philosophy instead of persisting degenerates and receives another character but if philosophy ever finds in the state that perfection which she herself is then will be seen that she is in truth divine and that all other things whether natures of men or institutions are but now i know that you
#
# are right and how can not the same thing which is a lover of accuracy is a mixture of the other and exclusive among the state and the other of the state and the other of the unreasoning anger of his depth is the permission to drink for soon as they are to be reserved for the interests of the state and the other of the state consisted in the argument to prefer to be
